# %%
#import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
from datetime import datetime

# %%
#install seaborn package
import seaborn as sns

# %%
#import libraries from vrious internet sources into a DataFrame

import pandas_datareader as pdr
import pandas_datareader.data as web

# %%
file = "../TSLA (1).csv"

# %%
df_tesla = pd.read_csv(file)

# %%
df_tesla.head(20)
# Out:
#           Date   Open   High    Low  Close  Adj Close    Volume
# 0   01/07/2010  5.000  5.184  4.054  4.392      4.392  41094000
# 1   02/07/2010  4.600  4.620  3.742  3.840      3.840  25699000
# 2   06/07/2010  4.000  4.000  3.166  3.222      3.222  34334500
# 3   07/07/2010  3.280  3.326  2.996  3.160      3.160  34608500
# 4   08/07/2010  3.228  3.504  3.114  3.492      3.492  38557000
# 5   09/07/2010  3.516  3.580  3.310  3.480      3.480  20253000
# 6   12/07/2010  3.590  3.614  3.400  3.410      3.410  11012500
# 7   13/07/2010  3.478  3.728  3.380  3.628      3.628  13400500
# 8   14/07/2010  3.588  4.030  3.552  3.968      3.968  20976000
# 9   15/07/2010  3.988  4.300  3.800  3.978      3.978  18699000
# 10  16/07/2010  4.140  4.260  4.010  4.128      4.128  13106500
# 11  19/07/2010  4.274  4.450  4.184  4.382      4.382  12432500
# 12  20/07/2010  4.370  4.370  4.010  4.060      4.060   9126500
# 13  21/07/2010  4.132  4.180  3.900  4.044      4.044   6262500
# ...

# %%
#Count number

df_tesla.count()
# Out:
# Date         2843
# Open         2843
# High         2843
# Low          2843
# Close        2843
# Adj Close    2843
# Volume       2843
# dtype: int64

# %%
#Create DataFrame

df = df_tesla.set_index("Date")
df.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 01/07/2010  5.000  5.184  4.054  4.392      4.392  41094000
# 02/07/2010  4.600  4.620  3.742  3.840      3.840  25699000
# 06/07/2010  4.000  4.000  3.166  3.222      3.222  34334500
# 07/07/2010  3.280  3.326  2.996  3.160      3.160  34608500
# 08/07/2010  3.228  3.504  3.114  3.492      3.492  38557000

# %%
# Drop any na if exits

df_na = df_tesla.dropna(how='any')
df_na.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  01/07/2010  5.000  5.184  4.054  4.392      4.392  41094000
# 1  02/07/2010  4.600  4.620  3.742  3.840      3.840  25699000
# 2  06/07/2010  4.000  4.000  3.166  3.222      3.222  34334500
# 3  07/07/2010  3.280  3.326  2.996  3.160      3.160  34608500
# 4  08/07/2010  3.228  3.504  3.114  3.492      3.492  38557000

# %%
#Check if the numbers has changed
df_na.count()
# Out:
# Date         2843
# Open         2843
# High         2843
# Low          2843
# Close        2843
# Adj Close    2843
# Volume       2843
# dtype: int64

# %%
#Count volumne of stock market

volume_df = df_na["Volume"].value_counts()
volume_df.head()
# Out:
# 23475000    2
# 16331500    2
# 28361500    2
# 3645000     2
# 28370000    2
# Name: Volume, dtype: int64

# %%
# Sorting the DataFrame based on "Volume" column
# Will sort from lowest to highest if no other parameter is passed
df_tesla.sort_values("Volume")
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 80    25/10/2010    4.188000    4.196000    4.146000    4.170000    4.170000
# 68    07/10/2010    4.114000    4.128000    4.068000    4.086000    4.086000
# 79    22/10/2010    4.136000    4.186000    4.110000    4.144000    4.144000
# 75    18/10/2010    4.104000    4.128000    4.044000    4.046000    4.046000
# 70    11/10/2010    4.088000    4.140000    4.014000    4.048000    4.048000
# ...          ...         ...         ...         ...         ...         ...
# 2416  06/02/2020  139.983994  159.166000  137.399994  149.792007  149.792007
# 2636  18/12/2020  668.900024  695.000000  628.539978  695.000000  695.000000
# 2413  03/02/2020  134.738007  157.227997  134.703995  156.000000  156.000000
# 2415  05/02/2020  164.651993  169.195999  140.822006  146.940002  146.940002
# 2414  04/02/2020  176.591995  193.798004  166.776001  177.412003  177.412003
#
#          Volume
# 80       592500
# ...

# %%
df_tesla.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2843.000000  2843.000000  2843.000000  2843.000000  2843.000000
# mean    105.868475   108.031370   103.555733   105.924597   105.924597
# std     188.738974   192.483055   184.638617   188.836358   188.836358
# min       3.228000     3.326000     2.996000     3.160000     3.160000
# 25%      10.698000    11.026000    10.420000    10.727000    10.727000
# 50%      45.874001    46.493999    45.102001    45.916000    45.916000
# 75%      65.021000    66.251999    64.015001    65.275002    65.275002
# max     891.380005   900.400024   871.599976   883.090027   883.090027
#
#              Volume
# count  2.843000e+03
# mean   3.141524e+07
# std    2.841880e+07
# min    5.925000e+05
# 25%    1.251050e+07
# 50%    2.481500e+07
# 75%    4.012025e+07
# max    3.046940e+08

# %%
#https://www.youtube.com/watch?v=sgndYho8RyI - Info do video do Yourtube - ver de novov para entener
#COVID
Ticker = "TSLA"
start = datetime(2019, 1, 1)

data2019 = pdr.get_data_yahoo(ticker, start)
data.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2018-12-31  67.842003  65.052002  67.557999  66.559998  31511500.0  66.559998
# 2019-01-02  63.026001  59.759998  61.220001  62.023998  58293000.0  62.023998
# 2019-01-03  61.880001  59.476002  61.400002  60.071999  34826000.0  60.071999
# 2019-01-04  63.599998  60.546001  61.200001  63.537998  36970500.0  63.537998
# 2019-01-07  67.348000  63.549999  64.344002  66.991997  37756000.0  66.991997

# %%
#Plotting Information during COVID 

data2019['Adj Close'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
# Setting the Start and End date for Stock Market Analysis
Ticker = "TSLA"
start = datetime(end.year-1,end.month,end.day)
end = datetime.now()

data = pdr.get_data_yahoo(ticker, start)
data.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-10-26  425.760010  410.000000  411.630005  420.279999  28239200
# 2020-10-27  430.500000  420.100006  423.760010  424.679993  22686500
# 2020-10-28  418.600006  406.000000  416.480011  406.019989  25451400
# 2020-10-29  418.059998  406.459991  409.959991  410.829987  22655300
# 2020-10-30  407.589996  379.109985  406.899994  388.040009  42511300
#
#              Adj Close
# Date
# 2020-10-26  420.279999
# 2020-10-27  424.679993
# 2020-10-28  406.019989
# 2020-10-29  410.829987
# 2020-10-30  388.040009

# %%
sns.relplot(data = data2019)

# %%
ticker = "TSLA"
start = datetime(end.year-1,end.month,end.day)

data2019 = pdr.get_data_yahoo(ticker, start)
data.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-10-26  425.760010  410.000000  411.630005  420.279999  28239200
# 2020-10-27  430.500000  420.100006  423.760010  424.679993  22686500
# 2020-10-28  418.600006  406.000000  416.480011  406.019989  25451400
# 2020-10-29  418.059998  406.459991  409.959991  410.829987  22655300
# 2020-10-30  407.589996  379.109985  406.899994  388.040009  42511300
#
#              Adj Close
# Date
# 2020-10-26  420.279999
# 2020-10-27  424.679993
# 2020-10-28  406.019989
# 2020-10-29  410.829987
# 2020-10-30  388.040009

# %%
# Plotting Adjusted Closing price for Tesla Motors Stock

data['Adj Close'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
# Plotting the total volume of stock being traded each day

data['Volume'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
# Plotting Daily returns as a function of Percent change in Adjusted Close value

data['Daily Return'] = data['Adj Close'].pct_change()

data['Daily Return'].plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla["Volume"].mean()
# Out:
# 31415237.42525501

# %%
df_tesla["Volume"].max()
# Out:
# 304694000

# %%
df_tesla["Volume"].std()
# Out:
# 28418797.352951575
